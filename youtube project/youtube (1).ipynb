# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:\\Users\\Deepthi\\OneDrive\\Desktop\\dataset\\youtube_recommendation_dataset -.csv")
print(df)
# Out:
#                                                  Title       channel_title  \
# 0    LA PERVERSA X LA INSUPERABLE X ALOFOKE MUSIC X...  AlofokeMusicSounds
# 1                              Moana | Official Teaser              Disney
# 2    $0 - $1 Trillion Only FISHING in Steal a Brain...          CaylusBlox
# 3                 ALLDAY PROJECT - ‘ONE MORE TIME’ M/V       THEBLACKLABEL
# 4        La Lupa | Vendetta Hero Trailer | Overwatch 2       PlayOverwatch
# ..                                                 ...                 ...
# 532                    Ghost of Yotei - Before You Buy            gameranx
# 533  ₹50,000 PS5 vs ₹2000 Game Stick 😲🤯 Who is the ...            Digidoty
# 534                       Arc Raiders - Before You Buy            gameranx
# 535                 Clair Obscur: Expedition 33 Review                 IGN
# 536  Must Play Mobile Game-Epic War!😎 #shorts #game...           MohanadPC
#
# ...

# %%
df.shape
# Out:
# (537, 16)

# %%
pd.set_option("display.max_rows",None)
df

# %%
df["published_at"].min()
# Out:
# '2012-10-24 14:20:11+00:00'

# %%
df.head(5)
# Out:
#                                                Title       channel_title  \
# 0  LA PERVERSA X LA INSUPERABLE X ALOFOKE MUSIC X...  AlofokeMusicSounds
# 1                            Moana | Official Teaser              Disney
# 2  $0 - $1 Trillion Only FISHING in Steal a Brain...          CaylusBlox
# 3               ALLDAY PROJECT - ‘ONE MORE TIME’ M/V       THEBLACKLABEL
# 4      La Lupa | Vendetta Hero Trailer | Overwatch 2       PlayOverwatch
#
#                 published_at  category_id  view_count  like_count  \
# 0  2025-11-16 15:34:55+00:00           10     1405647      140463
# 1  2025-11-17 17:00:47+00:00           24     2776847       26801
# 2  2025-11-17 22:57:14+00:00           20     1189857       16174
# 3  2025-11-17 09:00:07+00:00           10     5319161           0
# 4  2025-11-17 17:00:06+00:00           20      597542       41742
#
#    comment_count  favorite_count duration definition  caption  \
# 0           9063               0  PT1M51S         hd    False
# ...

# %%
df["comment_count"].max()
# Out:
# 810641

# %%
df["favorite_count"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 532    0
# 533    0
# 534    0
# 535    0
# 536    0
# Name: favorite_count, Length: 537, dtype: int64

# %%
df["engagement_rate"].min()
# Out:
# 0.0

# %%
df.keys()
# Out:
# Index(['Title', 'channel_title', 'published_at', 'category_id', 'view_count',
#        'like_count', 'comment_count', 'favorite_count', 'duration',
#        'definition', 'caption', 'engagement_rate', 'likes_to_views_ratio',
#        'comments_to_views_ratio', 'duration_seconds', 'video_age_days'],
#       dtype='object')

# %%
continous=["engagement_rate","likes_to_views_ratio","comments_to_views_ratio","duration_seconds","video_age_days"]
discrete_count=["view_count","like_count","comment_count","favorite_count"]
discrete_categorical=["Title","channel_title","category_id","duration","definition","caption"]
time_series=["published_at"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    537 non-null    object
#  1   channel_title            537 non-null    object
#  2   published_at             537 non-null    object
#  3   category_id              537 non-null    int64
#  4   view_count               537 non-null    int64
#  5   like_count               537 non-null    int64
#  6   comment_count            537 non-null    int64
#  7   favorite_count           537 non-null    int64
#  8   duration                 537 non-null    object
#  9   definition               537 non-null    object
#  10  caption                  537 non-null    bool
#  11  engagement_rate          537 non-null    float64
#  12  likes_to_views_ratio     537 non-null    float64
#  13  comments_to_views_ratio  537 non-null    float64
# ...

# %%
df["Title"].value_counts()
# Out:
# Title
# Must Play Mobile Game-Epic War!😎 #shorts #gamereviews                      3
# Python Full Course for free 🐍                                              2
# Watch Vaishnodevi Trip Vlog on @Neelam_kukreja 🤩 #priyalkukreja #shorts    2
# Age of Apes ads review new level: Banana Wars #games #gameape #gaming      1
# They Made A Fun Slot Even More Fun                                         1
#                                                                           ..
# Game of The Year 2025 is Going To Be A RIDICULOUS Fight                    1
# Ghost of Yotei - Before You Buy                                            1
# ₹50,000 PS5 vs ₹2000 Game Stick 😲🤯 Who is the Real Winner ?? #shorts       1
# Arc Raiders - Before You Buy                                               1
# ALLDAY PROJECT - ‘ONE MORE TIME’ M/V                                       1
# Name: count, Length: 533, dtype: int64

# %%
df["channel_title"].value_counts()
# Out:
# channel_title
# freeCodeCamp.org    22
# Apna College        18
# CodeWithHarry       12
# AOA Review           9
# Secret of yum        7
#                     ..
# DJ Precise           1
# ADRYNALYN            1
# Alan Walker          1
# Servida Stream       1
# Kyle Beats           1
# Name: count, Length: 344, dtype: int64

# %%
df["category_id"].value_counts()
# Out:
# category_id
# 27    150
# 22     99
# 20     57
# 24     54
# 10     51
# 26     47
# 28     36
# 17     15
# 1      10
# 19      8
# 23      6
# 25      4
# Name: count, dtype: int64

# %%
df["duration"].value_counts()
# Out:
# duration
# PT1M            29
# PT59S           17
# PT34S            7
# PT20S            7
# PT1M1S           7
# PT38S            7
# PT31S            6
# PT46S            6
# PT58S            5
# PT15S            5
# PT50S            5
# PT43S            5
# PT54S            5
# PT55S            5
# PT8S             5
# PT57S            4
# PT40S            4
# PT37S            4
# PT32S            4
# PT17S            4
# PT9S             4
# PT29S            3
# PT26S            3
# PT33S            3
# PT45S            3
# PT35S            3
# PT10S            3
# PT21S            3
# PT39S            3
# PT19S            3
# PT23S            3
# PT52S            3
# PT3M23S          3
# PT11S            3
# PT56S            3
# PT41S            3
# PT1M2S           2
# PT33M24S         2
# PT53S            2
# PT12M54S         2
# PT42S            2
# PT49S            2
# PT18S            2
# PT47S            2
# PT8M25S          2
# PT14S            2
# PT51S            2
# ...

# %%
df.isnull().sum()
# Out:
# Title                      0
# channel_title              0
# published_at               0
# category_id                0
# view_count                 0
# like_count                 0
# comment_count              0
# favorite_count             0
# duration                   0
# definition                 0
# caption                    0
# engagement_rate            0
# likes_to_views_ratio       0
# comments_to_views_ratio    0
# duration_seconds           0
# video_age_days             0
# dtype: int64

# %%
df[discrete_count].max()
# Out:
# view_count        369731024
# like_count         10879340
# comment_count        810641
# favorite_count            0
# dtype: int64

# %%
df[continous].max()
# Out:
# engagement_rate                 0.215744
# likes_to_views_ratio            0.199095
# comments_to_views_ratio         0.026031
# duration_seconds           105227.000000
# video_age_days               4772.000000
# dtype: float64

# %%
df[discrete_count].min()
# Out:
# view_count        0
# like_count        0
# comment_count     0
# favorite_count    0
# dtype: int64

# %%
df[continous].max()
# Out:
# engagement_rate                 0.215744
# likes_to_views_ratio            0.199095
# comments_to_views_ratio         0.026031
# duration_seconds           105227.000000
# video_age_days               4772.000000
# dtype: float64

# %%
df[continous].value_counts()
# Out:
# engagement_rate  likes_to_views_ratio  comments_to_views_ratio  duration_seconds  video_age_days
# 0.215744         0.199095              0.016649                 236               0                 1
# 0.000000         0.000000              0.000000                 0                 15                1
# 0.000010         0.000000              0.000010                 58                445               1
# 0.000070         0.000000              0.000070                 60                1646              1
# 0.000161         0.000000              0.000161                 57                629               1
#                                                                                                    ..
# 0.001750         0.001733              0.000017                 207               1                 1
# 0.000973         0.000925              0.000047                 5935              956               1
# ...

# %%
df.groupby("channel_title")[["view_count","like_count","comment_count"]].sum().sort_values("view_count", ascending=False).head()
# Out:
#                    view_count  like_count  comment_count
# channel_title
# Priyal Kukreja      614093089    11382359           9740
# Loveneet Valecha    533097184     4576147           8152
# SungBeats           369731024     3802072          22123
# Indian ASMR World   350693649     9668120          11173
# Зуфар Бек           328933013    10879340           8347

# %%
df.groupby("channel_title")[["view_count","like_count","comment_count"]].sum().sort_values("view_count", ascending=True).head()
# Out:
#                      view_count  like_count  comment_count
# channel_title
# World at War                  0           0              0
# KronosStyleKumuVEVO       27907         681             36
# Yeeps Official            31815        1326            492
# Cris Mejia - Topic        36443         600             24
# Emergency Awesome         39549        1586            237

# %%
df[df["channel_title"]=="Disney"]
# Out:
#                      Title channel_title               published_at  \
# 1  Moana | Official Teaser        Disney  2025-11-17 17:00:47+00:00
#
#    category_id  view_count  like_count  comment_count  favorite_count  \
# 1           24     2776847       26801           6684               0
#
#   duration definition  caption  engagement_rate  likes_to_views_ratio  \
# 1     PT1M         hd     True         0.012059              0.009652
#
#    comments_to_views_ratio  duration_seconds  video_age_days
# 1                 0.002407                60               0

# %%
df[(df["channel_title"]=="Disney")&(df["category_id"]==10)]
# Out:
# Empty DataFrame
# Columns: [Title, channel_title, published_at, category_id, view_count, like_count, comment_count, favorite_count, duration, definition, caption, engagement_rate, likes_to_views_ratio, comments_to_views_ratio, duration_seconds, video_age_days]
# Index: []

# %%
df[continous].describe()
# Out:
#        engagement_rate  likes_to_views_ratio  comments_to_views_ratio  \
# count       537.000000            537.000000               537.000000
# mean          0.028722              0.027692                 0.001030
# std           0.020608              0.019708                 0.002166
# min           0.000000              0.000000                 0.000000
# 25%           0.015579              0.015301                 0.000115
# 50%           0.024368              0.023565                 0.000398
# 75%           0.037366              0.036282                 0.000954
# max           0.215744              0.199095                 0.026031
#
#        duration_seconds  video_age_days
# count        537.000000      537.000000
# mean        4802.746741      934.050279
# std        13748.249437      904.546132
# min            0.000000        0.000000
# 25%           52.000000      261.000000
# 50%          390.000000      658.000000
# 75%         1639.000000     1363.000000
# ...

# %%
df[continous].describe()

# %%
len(df["category_id"].value_counts())
# Out:
# category_id
# 27    150
# 22     99
# 20     57
# 24     54
# 10     51
# 26     47
# 28     36
# 17     15
# 1      10
# 19      8
# 23      6
# 25      4
# Name: count, dtype: int64

# %%
df[["channel_title","view_count"]]
# Out:
#           channel_title  view_count
# 0    AlofokeMusicSounds     1405647
# 1                Disney     2776847
# 2            CaylusBlox     1189857
# 3         THEBLACKLABEL     5319161
# 4         PlayOverwatch      597542
# ..                  ...         ...
# 532            gameranx     1366391
# 533            Digidoty     1576718
# 534            gameranx     1218921
# 535                 IGN     1220485
# 536           MohanadPC     2157893
#
# [537 rows x 2 columns]

# %%
df[["channel_title","view_count","like_count","comment_count"]]
# Out:
#           channel_title  view_count  like_count  comment_count
# 0    AlofokeMusicSounds     1405647      140463           9063
# 1                Disney     2776847       26801           6684
# 2            CaylusBlox     1189857       16174           1827
# 3         THEBLACKLABEL     5319161           0          12869
# 4         PlayOverwatch      597542       41742           4728
# ..                  ...         ...         ...            ...
# 532            gameranx     1366391       45978           9598
# 533            Digidoty     1576718       32917            327
# 534            gameranx     1218921       28356           3146
# 535                 IGN     1220485       16187           2947
# 536           MohanadPC     2157893        7439             12
#
# [537 rows x 4 columns]

# %%
df[df["caption"]]["channel_title"]
# Out:
# 1              Disney
# 3       THEBLACKLABEL
# 4       PlayOverwatch
# 7             Netflix
# 13            HBO Max
#             ...
# 529       Dino Review
# 530    SsethTzeentach
# 531          gameranx
# 532          gameranx
# 534          gameranx
# Name: channel_title, Length: 115, dtype: object

# %%
df.sort_values(by="view_count")
# Out:
#                                                  Title        channel_title  \
# 32                                        World at War         World at War
# 30   Kronos_StyleKumul - Daddy Raus (Official Music...  KronosStyleKumuVEVO
# 25   YEEPS PLUSH PETS REVEALED | Official Launch Tr...       Yeeps Official
# 45                           Hace Tiempo En El Gabacho   Cris Mejia - Topic
# 34   IT Welcome To Derry Episode 5 Trailer: He’s Back!    Emergency Awesome
# ..                                                 ...                  ...
# 387  Watch Vaishnodevi Trip Vlog on @Neelam_kukreja...       Priyal Kukreja
# 287           THE REAL SPAGHETTI O’S ​@cookingwithkian               itsQCP
# 289  Hari mirche jyada daal di.🤣 #cooking #food #re...     Loveneet Valecha
# 337  Sigma #bek_zufarr #workout #motivation #sigma ...            Зуфар Бек
# 437  Making a beat with a BABY! 😭🤣 #beatbox #musicp...            SungBeats
#
# ...

# %%
df.sort_values(by=["view_count","like_count","comment_count"])
# Out:
#                                                  Title        channel_title  \
# 32                                        World at War         World at War
# 30   Kronos_StyleKumul - Daddy Raus (Official Music...  KronosStyleKumuVEVO
# 25   YEEPS PLUSH PETS REVEALED | Official Launch Tr...       Yeeps Official
# 45                           Hace Tiempo En El Gabacho   Cris Mejia - Topic
# 34   IT Welcome To Derry Episode 5 Trailer: He’s Back!    Emergency Awesome
# ..                                                 ...                  ...
# 387  Watch Vaishnodevi Trip Vlog on @Neelam_kukreja...       Priyal Kukreja
# 287           THE REAL SPAGHETTI O’S ​@cookingwithkian               itsQCP
# 289  Hari mirche jyada daal di.🤣 #cooking #food #re...     Loveneet Valecha
# 337  Sigma #bek_zufarr #workout #motivation #sigma ...            Зуфар Бек
# 437  Making a beat with a BABY! 😭🤣 #beatbox #musicp...            SungBeats
#
# ...

# %%
df["engagement_rate"].mean()
# Out:
# np.float64(0.028721672670422534)

# %%
df["likes_to_views_ratio"].median()
# Out:
# 0.02356495175

# %%
df["view_count"].mode()
# Out:
# 0              0
# 1          27907
# 2          31815
# 3          36443
# 4          39549
#          ...
# 532    265040795
# 533    272007073
# 534    277083247
# 535    328933013
# 536    369731024
# Name: view_count, Length: 537, dtype: int64

# %%
df["favorite_count"].std()
# Out:
# 0.0

# %%
df["comments_to_views_ratio"].var()
# Out:
# 4.690553540312559e-06

# %%
df["view_count"].skew()
# Out:
# np.float64(4.424063420626571)

# %%
df[["like_count","view_count"]].cov()
# Out:
#               like_count    view_count
# like_count  7.033691e+11  2.757348e+13
# view_count  2.757348e+13  1.612183e+15

# %%
df[["like_count","view_count"]].corr()
# Out:
#             like_count  view_count
# like_count    1.000000    0.818828
# view_count    0.818828    1.000000

# %%
df["view_count"].max()-df["view_count"].min()
# Out:
# 369731024

# %%
df.describe()_
# Out:
#        category_id    view_count    like_count  comment_count  favorite_count  \
# count   537.000000  5.370000e+02  5.370000e+02     537.000000           537.0
# mean     22.456238  2.145752e+07  4.336044e+05    7125.700186             0.0
# std       5.854776  4.015200e+07  8.386711e+05   36075.115032             0.0
# min       1.000000  0.000000e+00  0.000000e+00       0.000000             0.0
# 25%      20.000000  2.676921e+06  5.559100e+04    1018.000000             0.0
# 50%      24.000000  6.385911e+06  1.550550e+05    2354.000000             0.0
# 75%      27.000000  2.270604e+07  4.631890e+05    5925.000000             0.0
# max      28.000000  3.697310e+08  1.087934e+07  810641.000000             0.0
#
#        engagement_rate  likes_to_views_ratio  comments_to_views_ratio  \
# count       537.000000            537.000000               537.000000
# mean          0.028722              0.027692                 0.001030
# ...

# %%
df["view_count"].quantile(0)
# Out:
# np.float64(0.0)

# %%
Q1=df["view_count"].quantile(0.25)
Q1
# Out:
# np.float64(2676921.0)

# %%
Q3=df["view_count"].quantile(0.75)
Q3
# Out:
# np.float64(22706041.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(20029120.0)

# %%
LL=Q1-(IQR*1.5)
LL
# Out:
# np.float64(-27366759.0)

# %%
UL=Q3+(IQR*1.5)
UL

# %%
import seaborn as sns
print(sns.boxplot(x=df["view_count"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
import seaborn as sns
print(sns.boxplot(x=df["like_count"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
import seaborn as sns
sns.histplot(x=df["duration_seconds"],bins=7)
# Out:
# <Axes: xlabel='duration_seconds', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x=df["view_count"],bins=7)
# Out:
# <Axes: xlabel='view_count', ylabel='Count'>

# %%
sns.kdeplot(x=df["video_age_days"])
# Out:
# <Axes: xlabel='video_age_days', ylabel='Density'>

# %%
sns.kdeplot(x=df["engagement_rate"])
# Out:
# <Axes: xlabel='engagement_rate', ylabel='Density'>

# %%
sns.countplot(x=df["definition"])
# Out:
# <Axes: xlabel='definition', ylabel='count'>

# %%
sns.countplot(x=df["caption"])
# Out:
# <Axes: xlabel='caption', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.hist(df["comment_count"])
# Out:
# (array([535.,   1.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([     0. ,  81064.1, 162128.2, 243192.3, 324256.4, 405320.5,
#         486384.6, 567448.7, 648512.8, 729576.9, 810641. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["like_count"],bins=8,range=(10000,80000))
# Out:
# (array([14., 11., 22., 17., 20., 21., 17., 14.]),
#  array([10000., 18750., 27500., 36250., 45000., 53750., 62500., 71250.,
#         80000.]),
#  <BarContainer object of 8 artists>)

# %%
plt.xlabel("view_count")
# Out:
# Text(0.5, 0, 'view_count')

# %%
plt.xlabel("like_count")
# Out:
# Text(0.5, 0, 'like_count')

# %%
plt.title("DATA ANALYSIS ON YOUTUBE")
# Out:
# Text(0.5, 1.0, 'DATA ANALYSIS ON YOUTUBE')

# %%
plt.scatter(df["likes_to_views_ratio"],df["comments_to_views_ratio"])

# %%
plt.plot(df["like_count"],df["comment_count"],marker=0)

# %%
plt.scatter(x=df["view_count"],y=df["like_count"])
plt.xlabel("view_count")
plt.ylabel("likes_count")
# Out:
# Text(0, 0.5, 'likes_count')

# %%
plt.pie(x=df["caption"].value_counts(),labels=df["caption"].value_counts().index,autopct="%0.1f%%",explode=[0.05,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x211aad80980>,
# ...
#  [Text(-0.8994058374200538, 0.7166373836290791, 'False'),
#   Text(0.8603012957195921, -0.6854791613048431, 'True')],
#  [Text(-0.5083598211504651, 0.40505591248600126, '78.6%'),
#   Text(0.46925525221068654, -0.3738977243480962, '21.4%')])

# %%
df.isnull().sum()
# Out:
# Title                      0
# channel_title              0
# published_at               0
# category_id                0
# view_count                 0
# like_count                 0
# comment_count              0
# favorite_count             0
# duration                   0
# definition                 0
# caption                    0
# engagement_rate            0
# likes_to_views_ratio       0
# comments_to_views_ratio    0
# duration_seconds           0
# video_age_days             0
# dtype: int64
